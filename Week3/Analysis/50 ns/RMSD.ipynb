# %%
import mdtraj as md
import matplotlib.pyplot as plt
import numpy as np
import os
#f = open("potential.xvg", "r")
#print(f.read())
data=np.loadtxt("rmsd_50ns.xvg",skiprows=18)
xtaldata=np.loadtxt("rmsd_xtal_50ns.xvg",skiprows=18)
#print(data)
step=data[:,0]
rmsd=data[:,1]
rmsdxtal=xtaldata[:,1]
plt.plot(step,rmsd,label="Ref: Equilibrated")
plt.plot(step,rmsdxtal,label="Ref: Crystal")
plt.legend(loc="lower right")
plt.legend(loc="lower right")
plt.xlabel('Time (ns)')
plt.ylabel('RMSD (nm)')
plt.title('RMSD 1AKI_50ns_nowater, Backbone')
plt.xlim([0,50])
plt.savefig('RMSD 1AKI_50ns_nowater.pdf',format='pdf',bbox_inches='tight',pad_inches=0.1)
plt.show()
