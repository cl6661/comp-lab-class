# %%
import mdtraj as md
import matplotlib.pyplot as plt
import numpy as np
import os
#f = open("gyrate.xvg", "r")
#print(f.read())
data=np.loadtxt("gyrate.xvg",skiprows=27)
#print(data)
step=data[:,0]/1000
radius=data[:,1]
plt.plot(step,radius)
plt.xlabel('Time (ns)')
plt.ylabel('Radius of gyration (nm)')
plt.title('Radius of gyration 1AKI, Unrestrained MD')
plt.xlim([0,1])
plt.ylim([1.3,1.5])
plt.savefig('Radius of gyration 1AKI_tutorial.pdf',format='pdf',bbox_inches='tight',pad_inches=0.1)
plt.show()
