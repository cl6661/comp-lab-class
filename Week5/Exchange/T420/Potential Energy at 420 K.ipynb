# %%
import matplotlib.pyplot as plt
import numpy as np
import os

data = np.loadtxt("energy.xvg",skiprows=24)
print(data)

plt.hist(data[:,1],bins=100)
plt.xlabel('Potential Energy (kJ/mol)')
plt.ylabel('Count')
plt.title('Potential Energy Histogram at 420 K')
plt.savefig('Potential Energy Histogram at 420 K.pdf',format='pdf',bbox_inches='tight',pad_inches=0.1)
plt.show()
# Out:
# [[ 0.0000000e+00 -3.7616516e+01]
#  [ 1.0000000e+01 -1.2717987e+01]
#  [ 2.0000000e+01 -1.1510310e+00]
#  ...
#  [ 4.9800000e+03 -3.1329559e+01]
#  [ 4.9900000e+03 -7.1499330e+00]
#  [ 5.0000000e+03 -1.9434326e+01]]
